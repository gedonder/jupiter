# %% [markdown]
# # Timelines-pandas-matplotlib

# %% [markdown]
# 2018-01-12 13:58:29

# %%
# %matplotlib inline  

import plotly as py 
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.DataFrame(np.random.randn(7, 5),
                          index=['A', 'B', 'C', 'D', 'E', 'F', 'G'],
                          columns=[1, 2, 3, 4, 5])
df.head()

# %%
df.plot(title='hoi')

# %%
import matplotlib.pyplot as plt
# 1, 4
f = plt.figure(figsize=(10, 10)) # Change the size as necessary
# 2
df.plot(ax=f.gca()) # figure.gca means "get current axis"
plt.title('Title here!', color='red')

# %% [markdown]
# # Test data

# %% [markdown]
# ## Parse data time strings
# http://strftime.org

# %%
from datetime import datetime;
datetime_object = datetime.strptime('Jun 1 2005  1:33:12PM', '%b %d %Y %I:%M:%S%p')
datetime_object
# Out:
# datetime.datetime(2005, 6, 1, 13, 33, 12)

# %%
lijst=[]
tijden=[]

# %% [markdown]
# ## Create some test data

# %%
import time


for i in range(10):
    tijden.append(datetime.datetime.now())
    time.sleep(np.randint(5)) 
    lijst.append(np.random.randint(10))
#print tijden, lijst

# %% [markdown]
# # Time plots

# %% [markdown]
# ##  Simple plot

# %%
plt.plot(tijden,lijst)

# %% [markdown]
# more options
# https://matplotlib.org/devdocs/api/_as_gen/matplotlib.pyplot.plot.html

# %%
plt.plot(tijden,lijst,'-r+') # g groen r red  - streep o dot

# %%
plt.title('tijden')
plt.plot(tijden,lijst,'o')
# beautify the x-labels
plt.gcf().autofmt_xdate()

# %% [markdown]
# ## Sup plots

# %%
#x = [datetime.datetime.strptime(elem, '%a %b %d %H:%M:%S %Y') for elem in tijden]
#y=lijst
(fig, ax) = plt.subplots(1, 1)
ax.plot(tijden, lijst)
fig.show()

# %%
f, (ax1, ax2) = plt.subplots(2, sharex=True)
ax1.plot(tijden, lijst)
ax1.set_title('Sharing Y axis')
ax2.scatter(tijden, lijst)

# %%
fig, ax = plt.subplots()
ax.plot(np.random.rand(20), '-o', ms=20, lw=2, alpha=0.7, mfc='orange')
ax.grid()

# position bottom right
fig.text(0.95, 0.05, 'graph of 10A',
         fontsize=50, color='gray',
         ha='right', va='bottom', alpha=0.5)

plt.show()

# %% [markdown]
# https://stackoverflow.com/questions/32728212/how-to-plot-timestamps-in-python-using-matplotlib

# %% [markdown]
# # Test area

# %%
import matplotlib
dates = matplotlib.dates.date2num(lijst)
matplotlib.pyplot.plot_date(dates, values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-b4bd62afe501> in <module>()
#       1 import matplotlib
# ----> 2 dates = matplotlib.dates.date2num(lijst)
#       3 matplotlib.pyplot.plot_date(dates, values)
#
# AttributeError: 'module' object has no attribute 'dates'

# %%
fig, ax = plt.subplots()
ax.plot(np.random.rand(len(tijden)),tijden,'-o',ms=20,lw=2,alpha=0.7,mfc='orange')
ax.grid()
#%%!ax.format_xdata = tijden.DateFormatter('%Y-%m-%d')
ax.format_ydata = "hoi"
plt.show()

# %%
df = pd.DataFrame({'my_dates':['2015-01-01','2015-01-02','2015-01-03'],'myvals':[1,2,3]})
df['my_dates'] = pd.to_datetime(df['my_dates'])
df['day_of_week'] = df['my_dates'].dt.weekday_name

# %%
df2.my_dates.year
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b00fd67ef620> in <module>()
# ----> 1 df2.my_dates.year
#
# NameError: name 'df2' is not defined

# %%
df2=pd.DataFrame({'my_dates':tijden,'my_data':lijst})
times = pd.DatetimeIndex(df2.my_dates)
df2['date2']= pd.DatetimeIndex(df2.my_dates)
#df2['day'] = pd.to_datetime(df2['my_dates'])

#df2.groupby([times.hour, times.minute]).plot(kind='bar')
#df2.groupby([df2.date2.day]).plot(kind='bar')
df2[df2.groupby([df2.date2.day])
# Out:
#   File "<ipython-input-254-6cf2ac1c3c7c>", line 8
#     df2[df2.groupby([df2.date2.day])
#                                     ^
# SyntaxError: invalid syntax

# %%
#%%!grouped.
grouped.my_dates.day.plot()
#%%!grouped.h.plot(kind="bar")
df2['day']= df2[pd.to_datetime(df2.my_dates).day]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-faebd19d3c68> in <module>()
#       1 #%%!grouped.
# ----> 2 grouped.my_dates.day.plot()
#       3 #%%!grouped.h.plot(kind="bar")
#       4 df2['day']= df2[pd.to_datetime(df2.my_dates).day]
#       5
#
# NameError: name 'grouped' is not defined

# %%
df2=pd.DataFrame({'my_dates':tijden,'my_data':lijst})
temp = pd.DatetimeIndex(df2['my_dates'])
df2['weekday'] = temp.weekday
df2['day'] = temp.day

#%%!plt.plot(df2.groupby(df2.day).size(),kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-80d002c873e1> in <module>()
# ----> 1 df2=pd.DataFrame({'my_dates':tijden,'my_data':lijst})
#       2 temp = pd.DatetimeIndex(df2['my_dates'])
#       3 df2['weekday'] = temp.weekday
#       4 df2['day'] = temp.day
#       5
#
# NameError: name 'pd' is not defined

# %% [markdown]
# http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DatetimeIndex.html

# %%
df2.hist(column="day",        # Column to plot
              figsize=(15,4),         # Plot size
              color="blue")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1172047d0>]], dtype=object)
